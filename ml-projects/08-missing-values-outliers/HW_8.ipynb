# %% [markdown]
# ### В данной домашней работе Вам предстоит отработать следующие 2 навыка: работа с пропущенными значениями и анализ выбросов.

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('data/processed_data_with_new_features.csv', index_col='id')

# %%
data.head()
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1              NaN                   0     6.392080
# id3504673          1              NaN                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
#
#            log_trip_duration  anomaly  traffic_jam  day_of_week_1  \
# id
# id2875421           6.122493        0            0              0
# id2377394           6.498282        0            0              0
# id3858529           7.661527        0            1              1
# id3504673           6.063785        0            0              0
# id2181028           6.077642        0            0              0
#
#            day_of_week_2  day_of_week_3  ...  hour_19  hour_20  hour_21  \
# id                                       ...
# ...

# %% [markdown]
# Никудышный гном случайно пролил кофе на папку с данными и кодом. К несчастью, из-за этого они с братьями потеряли кучу информации в столбиках **passenger_count** и **distance_km**.

# %%
### Выведите количество пропусков в данных колонках
### На всякий случай, проверьте целостность данных в остальных

### Your code is here
data[['passenger_count','distance_km']].isna().sum()
# Out:
# passenger_count    145864
# distance_km        145864
# dtype: int64

# %% [markdown]
# Начнем с **passenger_count**. Вообще говоря, изначально это была категориальная колонка, к которой мы применили технику OneHotEncoder. Чтобы избавиться от пропусков в данных, конечно, можно просто убрать все объекты, в которых есть пропуски, но тогда мы потеряем ценную информацию.
#
# Воспользуйтесь относительно простым приемом из лекции: в указанной колонке заполните пропуски самым *популярным* значением среди неотсутствующих.

# %%
### Your code is here
popular = data['passenger_count'].value_counts().index[0]
data['passenger_count']=data['passenger_count'].fillna(popular)
data[['passenger_count','distance_km']].isna().sum()
# Out:
# passenger_count         0
# distance_km        145864
# dtype: int64

# %% [markdown]
# С колонкой **distance_km** поступим более интересным способом!
#
# Чтобы заполнить пропуск в данной колонке для того или иного объекта, можно находить наиболее похожий на него объект и подглядывать в его значение **distance_km**. Для того, чтобы понять, насколько объекты похожи друг на друга, необходимо использовать Евклидово расстояние между этими самыми объектами в пространстве всех признаков!
#
# С учетом количества объектов в нашем датасете и признаков, посчитать попарные расстояния будет мега-сложно. Поэтому давайте называть объекты похожими, если они принадлежат одной категории, составленной из следующих колонок:
#
# 1. vendor_id
# 2. store_and_fwd_flag
# 3. traffic_jam
# 4. month_2
# 5. month_3
# 6. month_4
# 7. month_5
# 8. month_6
#
# Внутри каждой группы найдите среднее значение признака **distance_km** и заполните NaN'ы в объектах с пропуском в соответствии с тем, к какой категории относится данный объект. Похожее упражнение мы делали на практике в занятии!
#
# **Hint**: достаточно просто взять group by по указанным выше категориальным колонкам и верно вставить полученный результат в исходную табличку.
#
# P.S. Колонки выбраны случайным образом. Можно было взять и другую комбинацию.

# %%
### Your code is here

grouped = data.groupby(['vendor_id','store_and_fwd_flag','traffic_jam','month_2','month_3','month_4','month_5','month_6'])['distance_km'].transform('mean')
data['distance_km']=data['distance_km'].fillna(grouped)
data[['passenger_count','distance_km']].isna().sum()
# Out:
# passenger_count    0
# distance_km        0
# dtype: int64

# %%
### Убедимся, что пропусков не осталось

### Your code is here
missing_values = data.isna().sum()
if missing_values.sum() > 0:
    print('Есть пропуски:')
    print(missing_values[missing_values > 0])
else:
    print('Пропусков нет')
# Out:
# Пропусков нет

# %% [markdown]
# ### Теперь наши данные чисты! Замерьте качество модели на Кросс-Валидации

# %%
from sklearn.model_selection import KFold

selector = KFold(n_splits=4, shuffle=True, random_state=33)

from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression

### Your code is here
X = data.drop('log_trip_duration', axis=1)
Y = data['log_trip_duration']

model = LinearRegression()
result = cross_validate(model, X, Y, cv=selector, scoring='neg_mean_squared_error')

cross_val_error = -np.mean(result['test_score'])

print(f"MSLE на Кросс-валидации: {round(cross_val_error, 3)}")
# Out:
# MSLE на Кросс-валидации: 0.431

# %%
print(f"Ошибки по фолдам: {[-score for score in result['test_score']]}")
# Out:
# Ошибки по фолдам: [0.4510481312622335, 0.4455532347070541, 0.4074174407609046, 0.41963126038826826]

# %% [markdown]
# ### Проведем анализ выбросов! Нарисуйте ящик с усами и гистограмму для таргетной переменной.

# %%
import matplotlib.pyplot as plt

### Your code is here
fig = plt.figure()

fig.set_size_inches(16, 20)

ax1 = fig.add_subplot(2,1,1)
plt.hist(data['log_trip_duration'], bins=100)
plt.ylim()

ax2 = fig.add_subplot(2,1,2)
plt.boxplot(data['log_trip_duration'])
plt.ylim()

fig.tight_layout()

ax1.set(title='гистограмма продолжительности поездки')
ax2.set(title='ящик с усами продолжительности поездки')

plt.show()

# %% [markdown]
# Есть ли, на ваш взгляд, в данных выбросы?
#
# Кажется, что да!
#
# Давайте почистим их, удалив те объекты, таргеты которых находятся вне промежутка
#
# (топ 99,5% значение;   топ 0,5% значение)

# %%
### Your code is here
low_quantile=data['log_trip_duration'].quantile(0.005)
upper_quantile=data['log_trip_duration'].quantile(0.995)
print(low_quantile,upper_quantile)
# Out:
# 3.9318256327243257 8.32845106681936

# %%
data = data[(data['log_trip_duration'] > low_quantile) & (data['log_trip_duration'] < upper_quantile)]
data
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1       930.399753                   0     6.392080
# id3504673          1       930.399753                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
# ...              ...              ...                 ...          ...
# id2376096          1       930.399753                   0     1.226296
# id1049543          0       930.399753                   0     6.056935
# id2304944          1       930.399753                   0     7.832952
# id2714485          0       930.399753                   0     1.093786
# id1209952          0       930.399753                   0     1.135453
#
#            log_trip_duration  anomaly  traffic_jam  day_of_week_1  \
# id
# ...

# %% [markdown]
# Снова замерьте качество на кросс-валидации, используя старый selector

# %%
### Your code is here
X_new = data.drop('log_trip_duration', axis=1)
Y_new = data['log_trip_duration']

model_new = LinearRegression()
result_new = cross_validate(model_new, X_new, Y_new, cv=selector, scoring='neg_mean_squared_error')

cross_val_error_new = -np.mean(result_new['test_score'])

print(f"MSLE на Кросс-валидации: {round(cross_val_error_new, 3)}")
# Out:
# MSLE на Кросс-валидации: 0.35
